# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HRDataset_v14.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.isnull()
# Out:
#      Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 0            False  False      False            False     False        False
# 1            False  False      False            False     False        False
# 2            False  False      False            False     False        False
# 3            False  False      False            False     False        False
# 4            False  False      False            False     False        False
# ..             ...    ...        ...              ...       ...          ...
# 306          False  False      False            False     False        False
# 307          False  False      False            False     False        False
# 308          False  False      False            False     False        False
# 309          False  False      False            False     False        False
# 310          False  False      False            False     False        False
#
# ...

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
fig = plt.figure(figsize=(3,5))
g = sns.histplot(df.Sex)
g.set_title('Gender Distribution');

# %%
fig = plt.figure(figsize=(3,5))
g = sns.histplot(df.Salary)
g.set_title('Gender Distribution');

# %%
#heat map
fig = plt.figure(figsize=(8,5))
g = sns.heatmap(df.corr());
g.set_title('correlation between continuous variables [Heat Map]')
# Out:
# <ipython-input-113-d5a424d11322>:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'correlation between continuous variables [Heat Map]')

# %%
#try to read the plot values
fig = plt.figure(figsize=(5,5))
g = sns.relplot(x="Sex",y="Department",kind='scatter',data=df);
g.fig.suptitle('Employees working in each department distinguished by Gender [Scatter Plot]',y=1.03);

# %%
import plotly.express as px
fig = px.sunburst(df, path=['Sex','Department','Absences', ],)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pie chart
fig = px.pie(df, values='Absences', names='Sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(df['PerfScoreID'].unique())
# Out:
# [4 3 2 1]

# %%
#violin plot
fig = plt.figure(figsize=(10,10))
g = sns.catplot(x="PerfScoreID",y="DeptID",kind='violin',order=[4, 3, 2, 1 ],data=df)
g.fig.suptitle('Performace distributions by Department [Violin Plot]')
# Out:
# Text(0.5, 0.98, 'Performace distributions by Department [Violin Plot]')

# %%
fig = px.pie(df, values='PerfScoreID', names='Department')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df, values='Salary', names='Department')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.relplot(data=df, x="SpecialProjectsCount", y="Department", hue="Sex", col="PerfScoreID")
g.fig.suptitle('Genderwise SpecialProjectsCount distributions of Department ')
# Out:
# Text(0.5, 0.98, 'Genderwise SpecialProjectsCount distributions of Department ')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.lmplot(x="Salary",y="GenderID",data=df)
g.fig.suptitle('Relationship b/w tip and total_bill [Scatter Plot + Regression Line]',y=1.05)
# Out:
# Text(0.5, 1.05, 'Relationship b/w tip and total_bill [Scatter Plot + Regression Line]')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.lmplot(x="PerfScoreID",y="GenderID",data=df)
g.fig.suptitle('Relationship b/w tip and total_bill [Scatter Plot + Regression Line]',y=1.05)

fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="DeptID",kind='count',order=[4, 3, 2, 1],data=df);
g.fig.suptitle("Frequency of days in the tips dataset [Count Plot]",y=1.05);

# %%
fig = px.sunburst(df, path=['PerformanceScore','Department', ],)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(df.Salary)
g.set_title('Salary Distribution');
# Out:
# <ipython-input-125-449ec67f4101>:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
fig = plt.figure(figsize=(8,5))
g = sns.jointplot(x="Salary",y="Department",data=df)
g.fig.suptitle('Relationship b/w Department and Salary along with distributions [Scatter Plot + Histograms]',y=1.05)
# Out:
# Text(0.5, 1.05, 'Relationship b/w Department and Salary along with distributions [Scatter Plot + Histograms]')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="DeptID",y="Absences",kind='swarm',order=[6, 5, 4, 3, 2, 1],ci=False,data=df)
g.fig.suptitle('Absentees by day along with tip distribution [Swarm Plot]',y=1.05)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning:
#
# 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# Text(0.5, 1.05, 'Absentees by day along with tip distribution [Swarm Plot]')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning:
#
# 35.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
fig = plt.figure(figsize=(10,10))
g = sns.catplot(x="PerfScoreID",y="Salary",kind='violin',order=[4, 3, 2, 1 ],data=df)
g.fig.suptitle('Performace distributions by Department [Violin Plot]')
# Out:
# Text(0.5, 0.98, 'Performace distributions by Department [Violin Plot]')

# %%
df2=df['Salary']
df2.describe()
# Out:
# count       311.000000
# mean      69020.684887
# std       25156.636930
# min       45046.000000
# 25%       55501.500000
# 50%       62810.000000
# 75%       72036.000000
# max      250000.000000
# Name: Salary, dtype: float64

# %%
#regression plot
fig = plt.figure(figsize=(8,5))
g = sns.scatterplot(x="GenderID",y="Salary",data=df)
g.fig.suptitle('Relationship b/w tip and total_bill [Scatter Plot + Regression Line]',y=1.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-710486732ca4> in <cell line: 4>()
#       2 fig = plt.figure(figsize=(8,5))
#       3 g = sns.scatterplot(x="GenderID",y="Salary",data=df)
# ----> 4 g.fig.suptitle('Relationship b/w tip and total_bill [Scatter Plot + Regression Line]',y=1.05)
#
# AttributeError: 'Axes' object has no attribute 'fig'

# %%
df['GenderID'].unique()
# Out:
# array([1, 0])

# %%
import plotly.express as px
df = px.data.tips()
fig = px.treemap(df, path=[px.Constant("all"), 'Sex', 'Department',],
                 values='GenderID', color='Department')
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
